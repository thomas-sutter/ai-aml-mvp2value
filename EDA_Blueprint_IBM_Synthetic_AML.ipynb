# %% [markdown]
# <a href="https://colab.research.google.com/github/thomas-sutter/ai-aml-mvp2value/blob/main/EDA_Blueprint_IBM_Synthetic_AML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IBM Synthetic Data — Core Banking & AML — **EDA Blueprint** (Iterative / Non‑Sequential)
#
# > **Purpose.** Professional, reproducible EDA for the IBM Synthetic Core Banking & AML dataset (CSV).
# > **Flow.** *Discovering → Joining → Validating → Structuring → Cleaning → Presenting* (iterate, don't treat as a strict sequence).
# > **Focus.** AML-relevant patterns (fan‑in / fan‑out / short cycles), label coherence, data quality, and next‑step recommendations.
#
# **Notebook Map**
# - 0️⃣ `0_Setup` (installs, imports, config, load CSVs)
# - 1️⃣ `1_Discovering` (overview profiles & first visuals)
# - 2️⃣ `2_Joining` (enrich xfers with accounts/banks/b2b)
# - 3️⃣ `3_Validating` (balances, FX, labels, rules)
# - 4️⃣ `4_Structuring` (windowed features & network cues)
# - 5️⃣ `5_Cleaning` (documented cleaning ops)
# - 6️⃣ `6_Presenting` (Sankey, network mini‑multiples, cohorts)
# - 7️⃣ `7_Findings_and_Next_Steps` (actionable summary)

# %% [markdown]
# ## 0_Setup

# %%
# Mount Google Drive to Colab notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Optional: uncomment any of these if not available in your Colab/runtime.
# !pip install --quiet pyarrow polars plotly networkx

import os, sys, math, json, textwrap, itertools, collections, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Try optional libs
try:
    import plotly.graph_objects as go
except Exception:
    go = None

try:
    import networkx as nx
except Exception:
    nx = None

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 220)
warnings.filterwarnings("ignore")

# ---- Paths (edit as needed) ----
DATA_PATH_CANDIDATES = {
    "bank_xfers": [
        "/content/sd175_Small_bank_xfers.csv",
        "/mnt/data/sd175_Small_bank_xfers.csv",
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_bank_xfers.csv", # Added Colab Drive path
        "./sd175_Small_bank_xfers.csv"
    ],
    "accts_people": [
        "/content/sd175_Small_liquid_accts_people.csv",
        "/mnt/data/sd175_Small_liquid_accts_people.csv",
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_people.csv", # Added Colab Drive path
        "./sd175_Small_liquid_accts_people.csv"
    ],
    "accts_companies": [
        "/content/sd175_Small_liquid_accts_companies.csv",
        "/mnt/data/sd175_Small_liquid_accts_companies.csv",
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_companies.csv", # Added Colab Drive path
        "./sd175_Small_liquid_accts_companies.csv"
    ],
    "b2b": [
        "/content/sd175_Small_b2b.csv",
        "/mnt/data/sd175_Small_b2b.csv",
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_b2b.csv", # Added Colab Drive path
        "./sd175_Small_b2b.csv"
    ],
    "banks": [
        "/content/sd175_Small_banks.csv",
        "/mnt/data/sd175_Small_banks.csv",
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_banks.csv", # Added Colab Drive path
        "./sd175_Small_banks.csv"
    ]
}


def pick_first_existing(paths):
    for p in paths:
        if os.path.exists(p):
            return p
    return None

PATHS = {k: pick_first_existing(v) for k,v in DATA_PATH_CANDIDATES.items()}
print("Resolved paths:", json.dumps(PATHS, indent=2))

# ---- Loaders ----
def read_csv_smart(path, parse_ts_cols=None, dtype=None):
    if path is None:
        return None
    parse_ts_cols = parse_ts_cols or []
    try:
        df = pd.read_csv(path, dtype=dtype, parse_dates=parse_ts_cols, low_memory=False)
    except UnicodeDecodeError:
        df = pd.read_csv(path, dtype=dtype, parse_dates=parse_ts_cols, encoding="latin-1", low_memory=False)
    return df

bank_xfers = read_csv_smart(PATHS["bank_xfers"], parse_ts_cols=["Timestamp"])
accts_people = read_csv_smart(PATHS["accts_people"])
accts_companies = read_csv_smart(PATHS["accts_companies"])
b2b = read_csv_smart(PATHS["b2b"])
banks = read_csv_smart(PATHS["banks"])

def data_overview(df, name):
    if df is None:
        print(f"[WARN] {name}: not loaded (path missing).")
        return
    print(f"--- {name} ---")
    print("shape:", df.shape)
    print("dtypes:\n", df.dtypes.head(20))
    print("head:\n", df.head(2))
    print()

for name, df in {
    "bank_xfers": bank_xfers,
    "accts_people": accts_people,
    "accts_companies": accts_companies,
    "b2b": b2b,
    "banks": banks
}.items():
    data_overview(df, name)

# ---- Data Dictionary utility ----
def build_data_dictionary(dfs):
    rows = []
    for name, df in dfs.items():
        if df is None:
            continue
        for col in df.columns:
            s = df[col]
            na_rate = float(s.isna().mean())
            nunique = int(s.nunique(dropna=True))
            sample_vals = ", ".join([str(v) for v in s.dropna().unique()[:5]])
            rows.append({
                "table": name,
                "column": col,
                "dtype": str(s.dtype),
                "missing_rate": round(na_rate, 6),
                "nunique": nunique,
                "examples": sample_vals
            })
    if not rows: # Add check for empty rows
        return pd.DataFrame(columns=["table", "column", "dtype", "missing_rate", "nunique", "examples"])
    dd = pd.DataFrame(rows).sort_values(["table", "column"]).reset_index(drop=True)
    return dd

data_dict = build_data_dictionary({
    "bank_xfers": bank_xfers,
    "accts_people": accts_people,
    "accts_companies": accts_companies,
    "b2b": b2b,
    "banks": banks
})
data_dict.head(20)
# Out:
# Resolved paths: {
#   "bank_xfers": "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_bank_xfers.csv",
#   "accts_people": "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_people.csv",
#   "accts_companies": "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_companies.csv",
#   "b2b": "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_b2b.csv",
#   "banks": "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_banks.csv"
# }
# --- bank_xfers ---
# shape: (1082800, 26)
# dtypes:
#  Timestamp               datetime64[ns]
# From_Bank                       object
# From_Account                     int64
# To_Bank                         object
# To_Account                       int64
# Amount_Paid                    float64
# Payment_Currency                object
# Amount_Received                float64
# Receiving_Currency              object
# Payment_Format                  object
# From_Initial_Balance           float64
# From_End_Balance               float64
# To_Initial_Balance             float64
# To_End_Balance                 float64
# Transaction_Type                object
# Laundering_Type                 object
# Is_Laundering                    int64
# Is_Cheque_Fraud                  int64
# Is_APP_Fraud                     int64
# Cheque_Fraudster_ID             object
# dtype: object
# head:
#                  Timestamp        From_Bank  From_Account             To_Bank  To_Account  Amount_Paid Payment_Currency  Amount_Received Receiving_Currency Payment_Format  From_Initial_Balance  From_End_Balance  \
# 0 2024-12-01 04:13:32.000  Dallas's Thrift    2617325812  Weber Savings Bank  1812019443      4072.59              USD          4072.59                USD            ACH              28576.80          24504.21
# 1 2024-12-01 02:28:57.700   Ally Financial    3556849909  Weber Savings Bank  1812019443      2243.06              USD          2243.06                USD            ACH              57699.59          55456.52
#
#    To_Initial_Balance  To_End_Balance Transaction_Type Laundering_Type  Is_Laundering  Is_Cheque_Fraud  Is_APP_Fraud Cheque_Fraudster_ID APP_Fraudster_ID  APP_Fraud_Sequence_Number  Sufficient_Funds  Overdraft_Okay  \
# 0            68447.38        72519.98   Forced Savings   No Laundering              0                0             0                   0                0                          0                 1               1
# 1            72519.98        74763.04   Forced Savings   No Laundering              0                0             0                   0                0                          0                 1               1
#
#    Is_All_Cash  Is_Hold
# 0            0        0
# 1            0        0
#
# --- accts_people ---
# shape: (5533, 15)
# dtypes:
#  Financial_Institution_Name        object
# Financial_Institution_ID          object
# Branch                            object
# Account_Country                   object
# Account_Currency                  object
# Entity_Type                       object
# Entity_ID                          int64
# Entity_Name                       object
# Does_Account_Have_Debit_Card       int64
# DebitCard_Index_in_EntityCards     int64
# Controlled_by_Criminal             int64
# MCC                                int64
# Account_Type                      object
# Account_ID                         int64
# Max_Overdraft                      int64
# dtype: object
# head:
#    Financial_Institution_Name Financial_Institution_ID     Branch Account_Country Account_Currency Entity_Type  Entity_ID       Entity_Name  Does_Account_Have_Debit_Card  DebitCard_Index_in_EntityCards  \
# 0                       Cash                 3CEC88A0   3CEC8BC0   United States              USD      Person          0  Ronald Alexander                             0                               0
# 1         Weber Savings Bank                696E7F1B0  696E7F540   United States              USD      Person          0  Ronald Alexander                             1                               0
#
#    Controlled_by_Criminal  MCC Account_Type  Account_ID  Max_Overdraft
# 0                       0    0         Cash           0              0
# 1                       0    0     Checking  1812019443            100
#
# --- accts_companies ---
# shape: (226533, 15)
# dtypes:
#  Financial_Institution_Name        object
# Financial_Institution_ID          object
# Branch                            object
# Account_Country                   object
# Account_Currency                  object
# Entity_Type                       object
# Entity_ID                         object
# Entity_Name                       object
# Does_Account_Have_Debit_Card       int64
# DebitCard_Index_in_EntityCards     int64
# Controlled_by_Criminal             int64
# MCC                                int64
# Account_Type                      object
# Account_ID                         int64
# Max_Overdraft                      int64
# dtype: object
# head:
#    Financial_Institution_Name Financial_Institution_ID     Branch Account_Country Account_Currency        Entity_Type  Entity_ID  Entity_Name  Does_Account_Have_Debit_Card  DebitCard_Index_in_EntityCards  \
# 0                   Key Bank                132879F10  134C391A0   United States              USD  Large_Corporation  1328AB520      Bechtel                             0                               0
# 1             SunTrust Banks                132879BD0  134C12020   United States              USD  Large_Corporation  1328AAEA0  D.R. Horton                             0                               0
#
#    Controlled_by_Criminal   MCC Account_Type  Account_ID  Max_Overdraft
# 0                       0  1520     Checking  3288334337            250
# 1                       0  1520     Checking  4093640706            100
#
# --- b2b ---
# shape: (186828, 25)
# dtypes:
#  B2B_Company_Index                   int64
# Company_ID                         object
# Company_Name                       object
# Company_MCC                         int64
# USD_Val_of_B2B_Payments_Recvd     float64
# USD_Val_of_B2B_Payments_Made      float64
# Number_of_B2B_Payments_Recvd      float64
# Number_of_B2B_Payments_Made       float64
# Number_of_B2B_Payments_Missed     float64
# Number_of_Main_Suppliers          float64
# Number_of_Main_B2B_Customers      float64
# Index_Number_of_Supplier          float64
# Supplier_Company_ID                object
# Supplier_Company_Name              object
# Supplier_Company_MCC              float64
# Supplier_Size_Category             object
# Supplier_Expctd_USD_Sell_to_Co    float64
# Supplier_Actual_USD_Sell_to_Co    float64
# Index_Number_of_B2B_Customer      float64
# B2B_Customer_Company_ID            object
# dtype: object
# head:
#     B2B_Company_Index Company_ID               Company_Name  Company_MCC  USD_Val_of_B2B_Payments_Recvd  USD_Val_of_B2B_Payments_Made  Number_of_B2B_Payments_Recvd  Number_of_B2B_Payments_Made  \
# 0                  1  1328AD380  Northrop Grumman - Site 1         1801                        10149.0                       24168.0                          25.0                        441.0
# 1                  1  1328AD380  Northrop Grumman - Site 1         1801                            NaN                           NaN                           NaN                          NaN
#
#    Number_of_B2B_Payments_Missed  Number_of_Main_Suppliers  Number_of_Main_B2B_Customers  Index_Number_of_Supplier Supplier_Company_ID            Supplier_Company_Name  Supplier_Company_MCC Supplier_Size_Category  \
# 0                            0.0                       6.0                           4.0                       NaN                 NaN                              NaN                   NaN                    NaN
# 1                            NaN                       NaN                           NaN                       1.0           85DE0B6A0  Brock's La Palma Legal Services                8111.0                  Small
#
#    Supplier_Expctd_USD_Sell_to_Co  Supplier_Actual_USD_Sell_to_Co  Index_Number_of_B2B_Customer B2B_Customer_Company_ID B2B_Customer_Company_Name  B2B_Customer_Company_MCC B2B_Customer_Size_Category  \
# 0                             NaN                             NaN                           NaN                     NaN                       NaN                       NaN                        NaN
# 1                          1115.0                          1533.0                           NaN                     NaN                       NaN                       NaN                        NaN
#
#    B2B_Cust_Expctd_USD_Buys_fr_Co  B2B_Cust_Actual_USD_Buys_fr_Co
# 0                             NaN                             NaN
# 1                             NaN                             NaN
#
# --- banks ---
# shape: (1458, 6)
# dtypes:
#  Bank_ID                        object
# Bank_Name                      object
# Num_Transactions                int64
# Num_Total_Locations             int64
# Num_non_Focus_Country_Locns     int64
# Sample_City                    object
# dtype: object
# head:
#       Bank_ID       Bank_Name  Num_Transactions  Num_Total_Locations  Num_non_Focus_Country_Locns                         Sample_City
# 0  132878850            Citi             66261                 2000                          100                      Paris - France
# 1  132877E90  JPMorgan Chase            130718                 2000                          100  Richmond - Indiana - United States
#               table                          column   dtype  missing_rate  nunique                                           examples
# 0   accts_companies                 Account_Country  object           0.0      198  United States, Sri Lanka, Algeria, Mongolia, C...
# 1   accts_companies                Account_Currency  object           0.0      143                            USD, EUR, LKR, RON, DZD
# 2   accts_companies                      Account_ID   int64           0.0   226463  3288334337, 4093640706, 2751463427, 1946157060...
# 3   accts_companies                    Account_Type  object           0.0        4              Checking, Money Market, Savings, Cash
# 4   accts_companies                          Branch  object           0.0    40063  134C391A0, 134C12020, 134A1A4D0, 134A48710, 13...
# 5   accts_companies          Controlled_by_Criminal   int64           0.0        2                                               0, 1
# 6   accts_companies  DebitCard_Index_in_EntityCards   int64           0.0        1                                                  0
# 7   accts_companies    Does_Account_Have_Debit_Card   int64           0.0        1                                                  0
# 8   accts_companies                       Entity_ID  object           0.0   110458  1328AB520, 1328AAEA0, 1328AB1E0, 1328AAB60, 13...
# 9   accts_companies                     Entity_Name  object           0.0    96054       Bechtel, D.R. Horton, Jacobs, Pulte, Skanska
# 10  accts_companies                     Entity_Type  object           0.0        6  Large_Corporation, Local_Government, National_...
# 11  accts_companies        Financial_Institution_ID  object           0.0    31529  132879F10, 132879BD0, 132877E90, 1328781D0, 13...
# 12  accts_companies      Financial_Institution_Name  object           0.0    15390  Key Bank, SunTrust Banks, JPMorgan Chase, Bank...
# 13  accts_companies                             MCC   int64           0.0      265                       1520, 1801, 3000, 3001, 3005
# 14  accts_companies                   Max_Overdraft   int64           0.0       63                          250, 100, 2000, 1000, 500
# 15     accts_people                 Account_Country  object           0.0       35  United States, Uruguay, Sierra Leone, Luxembou...
# 16     accts_people                Account_Currency  object           0.0       12                            USD, EUR, GBP, CNY, JPY
# 17     accts_people                      Account_ID   int64           0.0     5034  0, 1812019443, 2617325812, 3556849909, 2617325814
# 18     accts_people                    Account_Type  object           0.0        9  Cash, Checking, Savings, Money Market, Mutual ...
# 19     accts_people                          Branch  object           0.0     1303  3CEC8BC0, 696E7F540, 69992AE00, 133B57270, 69B...

# %% [markdown]
# ## 1_Discovering — First Look & Profiles

# %%
# --- Basic temporal and label distributions (bank_xfers) ---
if bank_xfers is not None and not bank_xfers.empty:
    bx = bank_xfers.copy()
    # Ensure Timestamp is datetime
    if "Timestamp" in bx.columns and not np.issubdtype(bx["Timestamp"].dtype, np.datetime64):
        bx["Timestamp"] = pd.to_datetime(bx["Timestamp"], errors="coerce")
    # Amounts
    amt_cols = [c for c in ["Amount_Paid","Amount_Received"] if c in bx.columns]
    print("Amount columns:", amt_cols)

    # Time range
    if "Timestamp" in bx.columns:
        print("Time span:", bx["Timestamp"].min(), "→", bx["Timestamp"].max())

    # Label distributions
    for lab in ["Is_Laundering", "Is_Cheque_Fraud", "Is_APP_Fraud", "Laundering_Type", "Transaction_Type"]:
        if lab in bx.columns:
            print(f"--- {lab} ---")
            print(bx[lab].value_counts(dropna=False).head(20))

    # Plots (matplotlib, no seaborn)
    fig = plt.figure(figsize=(6,4))
    if "Amount_Paid" in bx.columns:
        bx["Amount_Paid"].plot(kind="hist", bins=60)
        plt.title("Histogram: Amount_Paid")
        plt.xlabel("Amount_Paid")
    plt.show()

    fig = plt.figure(figsize=(6,4))
    if "Amount_Received" in bx.columns:
        bx["Amount_Received"].plot(kind="hist", bins=60)
        plt.title("Histogram: Amount_Received")
        plt.xlabel("Amount_Received")
    plt.show()

    # Time-of-day heatmap (weekday x hour)
    if "Timestamp" in bx.columns:
        tmp = bx.copy()
        tmp["weekday"] = tmp["Timestamp"].dt.weekday
        tmp["hour"] = tmp["Timestamp"].dt.hour
        pivot = tmp.pivot_table(index="weekday", columns="hour", values="From_Account", aggfunc="count").fillna(0)
        plt.figure(figsize=(10,3.8))
        plt.imshow(pivot.values, aspect="auto", interpolation="nearest")
        plt.title("Count of transactions — Weekday x Hour")
        plt.xlabel("Hour"); plt.ylabel("Weekday (0=Mon)")
        plt.colorbar()
        plt.show()

    # Top 20 Transaction_Type
    if "Transaction_Type" in bx.columns:
        top_types = bx["Transaction_Type"].value_counts().head(20)
        top_types.plot(kind="bar", figsize=(10,3.2))
        plt.title("Top 20 Transaction_Type (count)")
        plt.tight_layout(); plt.show()
# Out:
# Amount columns: ['Amount_Paid', 'Amount_Received']
# Time span: 2024-01-20 12:27:57.600000 → 2025-04-02 13:39:01.800000
# --- Is_Laundering ---
# Is_Laundering
# 0    1081578
# 1       1222
# Name: count, dtype: int64
# --- Is_Cheque_Fraud ---
# Is_Cheque_Fraud
# 0    1082376
# 1        424
# Name: count, dtype: int64
# --- Is_APP_Fraud ---
# Is_APP_Fraud
# 0    1082380
# 1        420
# Name: count, dtype: int64
# --- Laundering_Type ---
# Laundering_Type
# No Laundering     1081578
# Other                 459
# Gather Scatter        276
# Bipartite             241
# Fan-Out                99
# Scatter Gather         90
# Random                 32
# Fan-In                 25
# Name: count, dtype: int64
# --- Transaction_Type ---
# Transaction_Type
# Accounts Receivable     521328
# Accounts Payable        487597
# Personal Expense         49441
# Salary                    8498
# Bank Interest             5380
# Release of Hold           1863
# Buy Securities            1677
# Prepaid Card Refill       1387
# Money Laundering          1218
# Pay Credit Card Bill      1214
# Forced Savings            1201
# Cover Expenses             588
# IRA Contribution           492
# APP Fraud                  210
# Cheque Fraud               179
# Dividend Payment           170
# Sell Securities            159
# Funds from Illicit         124
# Bank Fee                    51
# Insurance Payout             7
# Name: count, dtype: int64

# %% [markdown]
# ## 2_Joining — Create `xfers_enriched` with account, bank, and B2B context

# %%
# === 2_Joining — SAFE DROP-IN (works even if 0_Setup didn't run) ===
import os, json
import pandas as pd

# ---------- Lazy loader (only loads if globals are missing) ----------
def read_csv_smart(path, parse_ts_cols=None, dtype=None):
    if not path:
        return None
    parse_ts_cols = parse_ts_cols or []
    try:
        return pd.read_csv(path, dtype=dtype, parse_dates=parse_ts_cols, low_memory=False)
    except UnicodeDecodeError:
        return pd.read_csv(path, dtype=dtype, parse_dates=parse_ts_cols, encoding="latin-1", low_memory=False)

# Your path candidates (incl. Drive); keep or adjust as needed.
DATA_PATH_CANDIDATES = {
    "bank_xfers": [
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_bank_xfers.csv",
        "/content/sd175_Small_bank_xfers.csv",
        "/mnt/data/sd175_Small_bank_xfers.csv",
        "./sd175_Small_bank_xfers.csv"
    ],
    "accts_people": [
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_people.csv",
        "/content/sd175_Small_liquid_accts_people.csv",
        "/mnt/data/sd175_Small_liquid_accts_people.csv",
        "./sd175_Small_liquid_accts_people.csv"
    ],
    "accts_companies": [
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_liquid_accts_companies.csv",
        "/content/sd175_Small_liquid_accts_companies.csv",
        "/mnt/data/sd175_Small_liquid_accts_companies.csv",
        "./sd175_Small_liquid_accts_companies.csv"
    ],
    "b2b": [
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_b2b.csv",
        "/content/sd175_Small_b2b.csv",
        "/mnt/data/sd175_Small_b2b.csv",
        "./sd175_Small_b2b.csv"
    ],
    "banks": [
        "/content/drive/MyDrive/Portfolio/AML/core_banking_and_money_laundering/data/sd175_Small_banks.csv",
        "/content/sd175_Small_banks.csv",
        "/mnt/data/sd175_Small_banks.csv",
        "./sd175_Small_banks.csv"
    ]
}

def _pick_first_existing(paths):
    for p in paths:
        if p and os.path.exists(p):
            return p
    return None

# Reuse existing PATHS if present; otherwise resolve now
if "PATHS" not in globals():
    PATHS = {k: _pick_first_existing(v) for k, v in DATA_PATH_CANDIDATES.items()}

# Load only if variables are missing in the kernel
g = globals()
if "bank_xfers" not in g:
    bank_xfers = read_csv_smart(PATHS.get("bank_xfers"), ["Timestamp"])
if "accts_people" not in g:
    accts_people = read_csv_smart(PATHS.get("accts_people"))
if "accts_companies" not in g:
    accts_companies = read_csv_smart(PATHS.get("accts_companies"))
if "b2b" not in g:
    b2b = read_csv_smart(PATHS.get("b2b"))
if "banks" not in g:
    banks = read_csv_smart(PATHS.get("banks"))

# ---------- Join helpers ----------
def _prefix_join(df_left, df_right, left_key, right_key, prefix):
    """Left join with prefixed right columns. Safe if df_right is None/empty or keys missing."""
    if df_left is None or df_left.empty or df_right is None or df_right.empty:
        return df_left
    if left_key not in df_left.columns or right_key not in df_right.columns:
        return df_left
    cols_right = [c for c in df_right.columns if c != right_key]
    renamed = {c: f"{prefix}{c}" for c in cols_right}
    out = df_left.merge(df_right, how="left", left_on=left_key, right_on=right_key)
    out = out.rename(columns=renamed).drop(columns=[right_key], errors="ignore")
    return out

def build_xfers_enriched(bank_xfers, accts_people=None, accts_companies=None, banks=None, b2b=None):
    """Enrich transfers with account/bank/B2B context; returns (df, join_report)."""
    if bank_xfers is None or bank_xfers.empty:
        return None, {"error": "bank_xfers is empty or not loaded"}

    x = bank_xfers.copy()
    join_report = {}

    # Accounts concat
    accounts = None
    if isinstance(accts_people, pd.DataFrame):
        accounts = accts_people.copy()
    if isinstance(accts_companies, pd.DataFrame):
        accounts = pd.concat([accounts, accts_companies], axis=0) if accounts is not None else accts_companies.copy()

    if isinstance(accounts, pd.DataFrame) and "Account_ID" in accounts.columns:
        before = len(x)
        x = _prefix_join(x, accounts, "From_Account", "Account_ID", "from_")
        x = _prefix_join(x, accounts, "To_Account", "Account_ID", "to_")
        join_report["accounts_join_rows"] = {"before": before, "after": len(x)}
    else:
        join_report["accounts_join_rows"] = "skipped (no accounts or missing Account_ID)"

    # Banks metadata
    if isinstance(banks, pd.DataFrame) and "Bank_ID" in banks.columns:
        x = _prefix_join(x, banks, "From_Bank", "Bank_ID", "from_bank_")
        x = _prefix_join(x, banks, "To_Bank", "Bank_ID", "to_bank_")
    else:
        join_report["banks_join"] = "skipped (missing Bank_ID)"

    # B2B overlay (optional)
    if isinstance(b2b, pd.DataFrame) and "Company_ID" in b2b.columns:
        if "from_Entity_ID" in x.columns:
            x = x.merge(b2b.add_prefix("from_company_"), how="left",
                        left_on="from_Entity_ID", right_on="from_company_Company_ID")
        if "to_Entity_ID" in x.columns:
            x = x.merge(b2b.add_prefix("to_company_"), how="left",
                        left_on="to_Entity_ID", right_on="to_company_Company_ID")
    else:
        join_report["b2b_join"] = "skipped (missing Company_ID or b2b)"

    return x, join_report

# ---------- Execute safely ----------
if "bank_xfers" not in globals() or bank_xfers is None:
    raise RuntimeError("`bank_xfers` konnte nicht geladen werden. Prüfe Pfade in DATA_PATH_CANDIDATES oder führe 0_Setup aus.")

xfers_enriched, join_report = build_xfers_enriched(bank_xfers, accts_people, accts_companies, banks, b2b)
print("Join report:", json.dumps(join_report, indent=2))
xfers_enriched.head(3) if xfers_enriched is not None else None

# %% [markdown]
# ## 3_Validating — Balances, FX, Label Coherence, Rule Checks

# %%
def validate_balances(df, tol=1e-6):
    issues = []
    if df is None or df.empty:
        return pd.DataFrame(issues)

    need = {"From_Initial_Balance","From_End_Balance","Amount_Paid","To_Initial_Balance","To_End_Balance","Amount_Received"}
    if not need.issubset(df.columns):
        return pd.DataFrame(issues)

    exp_from_end = df["From_Initial_Balance"] - df["Amount_Paid"]
    exp_to_end = df["To_Initial_Balance"] + df["Amount_Received"]
    bad_from = (df["From_End_Balance"] - exp_from_end).abs() > tol
    bad_to = (df["To_End_Balance"] - exp_to_end).abs() > tol

    if bad_from.any():
        issues.append({"issue":"from_balance_mismatch","rows":int(bad_from.sum()),"rate":float(bad_from.mean())})
    if bad_to.any():
        issues.append({"issue":"to_balance_mismatch","rows":int(bad_to.sum()),"rate":float(bad_to.mean())})

    return pd.DataFrame(issues)

def validate_fx(df, z_thresh=4.0):
    issues = []
    if df is None or df.empty:
        return pd.DataFrame(issues)
    need = {"Payment_Currency","Receiving_Currency","Amount_Paid","Amount_Received"}
    if not need.issubset(df.columns):
        return pd.DataFrame(issues)

    mask = (df["Payment_Currency"].notna() & df["Receiving_Currency"].notna() & (df["Amount_Paid"]>0))
    sub = df.loc[mask].copy()
    if sub.empty:
        return pd.DataFrame(issues)

    sub["implied_fx"] = sub["Amount_Received"] / sub["Amount_Paid"]
    # Compute z-score per currency pair
    sub["pair"] = sub["Payment_Currency"].astype(str) + "→" + sub["Receiving_Currency"].astype(str)
    out_rows = []
    for pair, grp in sub.groupby("pair"):
        m = grp["implied_fx"].mean()
        s = grp["implied_fx"].std(ddof=0)
        if s == 0 or np.isnan(s):
            continue
        z = (grp["implied_fx"] - m) / s
        outliers = (z.abs() > z_thresh)
        if outliers.any():
            out_rows.append({"pair": pair, "outlier_rows": int(outliers.sum()), "rate": float(outliers.mean())})
    return pd.DataFrame(out_rows)

def validate_labels(df):
    issues = []
    if df is None or df.empty:
        return pd.DataFrame(issues)
    if "Is_Laundering" in df.columns and "Laundering_Type" in df.columns:
        bad = (df["Is_Laundering"]==1) & (df["Laundering_Type"].isna() | (df["Laundering_Type"].astype(str).str.lower().isin(["", "none", "clean"])))
        if bad.any():
            issues.append({"issue":"laundering_label_without_type","rows":int(bad.sum()),"rate":float(bad.mean())})
    return pd.DataFrame(issues)

def validate_rules(df):
    issues = []
    if df is None or df.empty:
        return pd.DataFrame(issues)
    for cols, name in [
        (["Sufficient_Funds","Overdraft_Okay"], "insufficient_and_no_overdraft"),
        (["Is_All_Cash","Payment_Format"], "cash_vs_payment_format"),
        (["Is_Hold"], "holds_present")
    ]:
        for c in cols:
            if c not in df.columns:
                break
        # Example: count insufficient funds with overdraft not ok but transaction succeeded (heuristic)
    if set(["Sufficient_Funds","Overdraft_Okay"]).issubset(df.columns):
        bad = (df["Sufficient_Funds"]==0) & (df["Overdraft_Okay"]==0)
        issues.append({"issue":"insufficient_funds_and_no_overdraft", "rows": int(bad.sum()), "rate": float(bad.mean())})
    if "Is_All_Cash" in df.columns and "Payment_Format" in df.columns:
        bad = (df["Is_All_Cash"]==1) & (~df["Payment_Format"].astype(str).str.lower().str.contains("cash"))
        issues.append({"issue":"all_cash_but_format_not_cash", "rows": int(bad.sum()), "rate": float(bad.mean())})
    if "Is_Hold" in df.columns:
        holds = (df["Is_Hold"]==1)
        issues.append({"issue":"holds_flagged", "rows": int(holds.sum()), "rate": float(holds.mean())})
    return pd.DataFrame(issues)

def build_issue_log(df):
    parts = []
    for fn in [validate_balances, validate_fx, validate_labels, validate_rules]:
        try:
            res = fn(df)
            if res is not None and not res.empty:
                parts.append(res)
        except Exception as e:
            parts.append(pd.DataFrame([{"issue":f"{fn.__name__}_error", "rows":-1, "rate":-1.0, "error":str(e)}]))
    if parts:
        out = pd.concat(parts, ignore_index=True)
        out = out.sort_values(by=["rows"], ascending=False)
    else:
        out = pd.DataFrame(columns=["issue","rows","rate"])
    return out

issue_log = build_issue_log(bank_xfers if bank_xfers is not None else xfers_enriched)
issue_log.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1873752692.py in <cell line: 0>()
#      98     return out
#      99
# --> 100 issue_log = build_issue_log(bank_xfers if bank_xfers is not None else xfers_enriched)
#     101 issue_log.head(20)
#
# NameError: name 'bank_xfers' is not defined

# %%
# === 3_Validating — SAFE DROP-IN (no NameError if bank_xfers is missing) ===
import pandas as pd
import numpy as np

# ---------------- Validation helpers ----------------
def validate_balances(df, tol=1e-6):
    issues = []
    if df is None or df.empty:
        return pd.DataFrame(issues)

    need = {"From_Initial_Balance","From_End_Balance","Amount_Paid",
            "To_Initial_Balance","To_End_Balance","Amount_Received"}
    if not need.issubset(df.columns):
        return pd.DataFrame(issues)

    exp_from_end = df["From_Initial_Balance"] - df["Amount_Paid"]
    exp_to_end   = df["To_Initial_Balance"]   + df["Amount_Received"]
    bad_from = (df["From_End_Balance"] - exp_from_end).abs() > tol
    bad_to   = (df["To_End_Balance"] - exp_to_end).abs() > tol

    if bad_from.any():
        issues.append({"issue":"from_balance_mismatch",
                       "rows":int(bad_from.sum()), "rate":float(bad_from.mean())})
    if bad_to.any():
        issues.append({"issue":"to_balance_mismatch",
                       "rows":int(bad_to.sum()), "rate":float(bad_to.mean())})
    return pd.DataFrame(issues)

def validate_fx(df, z_thresh=4.0):
    if df is None or df.empty:
        return pd.DataFrame()
    need = {"Payment_Currency","Receiving_Currency","Amount_Paid","Amount_Received"}
    if not need.issubset(df.columns):
        return pd.DataFrame()

    mask = (df["Payment_Currency"].notna() &
            df["Receiving_Currency"].notna() &
            (df["Amount_Paid"] > 0))
    sub = df.loc[mask].copy()
    if sub.empty:
        return pd.DataFrame()

    sub["implied_fx"] = sub["Amount_Received"] / sub["Amount_Paid"]
    sub["pair"] = sub["Payment_Currency"].astype(str) + "→" + sub["Receiving_Currency"].astype(str)

    rows = []
    for pair, grp in sub.groupby("pair"):
        m = grp["implied_fx"].mean()
        s = grp["implied_fx"].std(ddof=0)
        if s == 0 or np.isnan(s):
            continue
        z = (grp["implied_fx"]_]()

# %% [markdown]
# ## 4_Structuring — Windowed Features & Network Signals

# %%
def make_long_edges(df):
    # Convert transfers into a long 'account-centric' table for windowed rollups
    need = ["Timestamp","From_Account","To_Account","Amount_Paid","Amount_Received"]
    miss = [c for c in need if c not in df.columns]
    if miss:
        raise ValueError(f"Missing columns: {miss}")
    x = df.copy()
    x["Timestamp"] = pd.to_datetime(x["Timestamp"], errors="coerce")
    # Outgoing leg
    out = x[["Timestamp","From_Account","To_Account","Amount_Paid"]].rename(
        columns={"From_Account":"account_id","To_Account":"counterparty_id","Amount_Paid":"amount"})
    out["direction"] = "out"
    # Incoming leg
    inc = x[["Timestamp","To_Account","From_Account","Amount_Received"]].rename(
        columns={"To_Account":"account_id","From_Account":"counterparty_id","Amount_Received":"amount"})
    inc["direction"] = "in"
    long_df = pd.concat([out, inc], ignore_index=True)
    long_df = long_df.sort_values("Timestamp")
    return long_df

def rolling_features(long_df, window="7D"):
    if long_df is None or long_df.empty:
        return pd.DataFrame()
    long_df = long_df.dropna(subset=["Timestamp"])
    long_df = long_df.sort_values("Timestamp")
    # Group by account_id & direction
    feats = []
    for (acc, direction), g in long_df.groupby(["account_id","direction"], sort=False):
        g = g.set_index("Timestamp").sort_index()
        # Basic rolling sums and counts
        g["amount_sum"] = g["amount"].rolling(window=window).sum()
        g["tx_count"] = g["amount"].rolling(window=window).count()
        # Unique counterparties over window (approx via expanding set on day granularity)
        daily = g.resample("1D").agg({"amount":"sum","counterparty_id": lambda s: s.nunique()})
        daily["burstiness"] = daily["amount"].rolling(window=7).max() / (daily["amount"].rolling(window=7).mean()+1e-9)
        df_feat = pd.DataFrame({
            "account_id": acc,
            "direction": direction,
            "ts": daily.index,
            "sum_amount_1D": daily["amount"],
            "unique_cpty_1D": daily["counterparty_id"],
            "burstiness_7D": daily["burstiness"]
        })
        feats.append(df_feat.reset_index(drop=True))
    return pd.concat(feats, ignore_index=True) if feats else pd.DataFrame()

def fan_in_out_scores(long_df, ref_window="7D"):
    if long_df is None or long_df.empty:
        return pd.DataFrame()
    # Count unique counterparties per account over the whole dataset (approx static score)
    grp = long_df.groupby(["account_id","direction"])["counterparty_id"].nunique().unstack(fill_value=0)
    grp = grp.rename(columns={"in":"unique_in","out":"unique_out"})
    grp["fan_in_score"] = grp.get("unique_in", 0)
    grp["fan_out_score"] = grp.get("unique_out", 0)
    return grp.reset_index()

# Build
if bank_xfers is not None:
    long_df = make_long_edges(bank_xfers)
    roll7 = rolling_features(long_df, window="7D")
    fan_scores = fan_in_out_scores(long_df)
    print("roll7 shape:", roll7.shape, "fan_scores shape:", fan_scores.shape)
    fan_scores.sort_values("fan_out_score", ascending=False).head(10)

# %%
def build_graph_for_sample(df, sample_n=3000):
    if nx is None:
        print("[INFO] networkx not available; skip graph.")
        return None
    if df is None or df.empty:
        return None
    cols = ["From_Account","To_Account","Amount_Paid","Amount_Received","Timestamp","Is_Laundering","Laundering_Type"]
    cols = [c for c in cols if c in df.columns]
    sample = df[cols].sample(min(sample_n, len(df)), random_state=42)
    G = nx.DiGraph()
    for _, r in sample.iterrows():
        u = r.get("From_Account"); v = r.get("To_Account")
        if pd.isna(u) or pd.isna(v):
            continue
        G.add_edge(u, v, amount=float(r.get("Amount_Paid", 0)), ts=r.get("Timestamp", None),
                   is_laund=int(r.get("Is_Laundering", 0)) if not pd.isna(r.get("Is_Laundering", np.nan)) else 0,
                   ltype=str(r.get("Laundering_Type", "")))
    return G

def simple_cycle_counts(G, max_len=5, limit=5000):
    if G is None:
        return pd.DataFrame()
    cycles = []
    for i, cyc in enumerate(nx.simple_cycles(G)):
        if i>limit: break
        if 2 <= len(cyc) <= max_len:
            cycles.append(cyc)
    # Count participation per node
    counts = {}
    for cyc in cycles:
        for node in cyc:
            counts[node] = counts.get(node, 0) + 1
    out = pd.DataFrame([{"account_id":k, "cycle_count":v} for k,v in counts.items()]).sort_values("cycle_count", ascending=False)
    return out

G = build_graph_for_sample(bank_xfers, sample_n=5000) if bank_xfers is not None else None
cycle_rank = simple_cycle_counts(G, max_len=5, limit=3000) if G is not None else pd.DataFrame()
cycle_rank.head(10)

# %% [markdown]
# ## 5_Cleaning — Documented Operations

# %%
def clean_bank_xfers(df):
    x = df.copy()
    # Normalize string empties to NaN
    for c in x.select_dtypes(include=["object"]).columns:
        x[c] = x[c].replace({"": np.nan, "NA": np.nan, "None": np.nan})
    # Ensure Timestamp dtype
    if "Timestamp" in x.columns:
        x["Timestamp"] = pd.to_datetime(x["Timestamp"], errors="coerce")
    # Remove duplicates (conservative)
    x = x.drop_duplicates()
    # Optional: clip extreme amounts for EDA plots only (not for modeling!)
    if "Amount_Paid" in x.columns:
        q_hi = x["Amount_Paid"].quantile(0.999)
        x["_Amount_Paid_plot"] = x["Amount_Paid"].clip(upper=q_hi)
    if "Amount_Received" in x.columns:
        q_hi2 = x["Amount_Received"].quantile(0.999)
        x["_Amount_Received_plot"] = x["Amount_Received"].clip(upper=q_hi2)
    return x

bank_xfers_clean = clean_bank_xfers(bank_xfers) if bank_xfers is not None else None
bank_xfers_clean.head(3) if bank_xfers_clean is not None else None

# %% [markdown]
# ## 6_Presenting — Sankey, Network Samples, Cohorts

# %%
# Sankey From_Bank → To_Bank (volume)
def sankey_bank_to_bank(df, top_n=12):
    if go is None:
        print("[INFO] plotly not available; skip sankey.")
        return None
    need = {"From_Bank","To_Bank","Amount_Paid"}
    if not need.issubset(df.columns):
        print("[WARN] Missing columns for Sankey:", need - set(df.columns))
        return None
    agg = df.groupby(["From_Bank","To_Bank"])["Amount_Paid"].sum().reset_index()
    agg = agg.sort_values("Amount_Paid", ascending=False).head(top_n)
    labels = list(pd.unique(agg[["From_Bank","To_Bank"]].values.ravel("K")))
    label_idx = {lab:i for i, lab in enumerate(labels)}
    source = agg["From_Bank"].map(label_idx).tolist()
    target = agg["To_Bank"].map(label_idx).tolist()
    value = agg["Amount_Paid"].tolist()
    fig = go.Figure(data=[go.Sankey(
        node=dict(pad=15, thickness=15, label=labels),
        link=dict(source=source, target=target, value=value)
    )])
    fig.update_layout(title_text="Top Bank→Bank Flows (by Amount_Paid)", font_size=10)
    return fig

if bank_xfers_clean is not None:
    fig = sankey_bank_to_bank(bank_xfers_clean, top_n=14)
    fig.show() if fig is not None else None

# %% [markdown]
# ## 7_Findings_and_Next_Steps — Checklist

# %% [markdown]
# **Top Findings (fill as you iterate):**
# - [ ] Data coverage: time range, currencies, formats
# - [ ] Label distribution & imbalance quantified
# - [ ] Balance / FX sanity checks summary
# - [ ] Fan‑in / fan‑out hubs and top cycle participants
# - [ ] Suspicious patterns (accounts, banks, countries)
#
# **Concrete Recommendations:**
# - [ ] Feature candidates (name, window, rationale) -> export as CSV (feature_catalog.csv)
# - [ ] Evaluation plan (time‑split; PR‑AUC/F1; calibration)
# - [ ] Governance notes (ground‑truth usage, bias checks, documentation)
